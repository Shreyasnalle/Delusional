# %%
from get_dataset import load_aml_dataset
df = load_aml_dataset("HI-Medium_Trans.csv")
# Out:
# ...
# Resuming download from 61865984 bytes (8114303434 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/ealtman2019/ibm-transactions-for-anti-money-laundering-aml?dataset_version_number=8 (61865984/8176169418) bytes left.
#   1%|          | 61.0M/7.61G [00:01<1:52:13, 1.20MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from get_dataset import load_aml_dataset
# ----> 2 df = load_aml_dataset("HI-Medium_Trans.csv")
#
# File ~/Desktop/Delusional/model/get_dataset.py:8, in load_aml_dataset(file_name)
#       7 def load_aml_dataset(file_name = "HI-Medium_Trans.csv"):
# ----> 8     dataset_dir = kagglehub.dataset_download(DATASET_HANDLE)
#      10     csv_file_path = os.path.join(dataset_dir, file_name)
#      11     if not os.path.exists(csv_file_path):
#
# ...

# %%
print(f"Dimensions of the DataFrame: {df.shape}")
