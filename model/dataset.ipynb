# %%
from get_dataset import load_aml_dataset
df = load_aml_dataset()
# Out:
# ...
# 100%|██████████| 15.9G/15.9G [48:06<00:00, 5.91MB/s]

# %%
print(f"the dimensions of HI large df : {df.shape}")
# Out:
# the dimensions of HI large df : (15000000, 11)
